# %% [markdown]
# <a href="https://colab.research.google.com/github/katherinehoog/VKPM/blob/main/VKJM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports & Data files

# %%
import pandas as pd
import random
import math

from google.colab import files

# %%
#uploaded = files.upload()

# %% [markdown]
# # DataFrame manipulation

# %%
def genreDF(genre):
  import numpy as np

  movies_DF = pd.DataFrame(pd.read_csv('IMDb movies.csv')) # Download the dataframe
  movies_DF = movies_DF[['title', 'genre', 'language', 'description']].copy()
  # could also use 'duration' and print how long the movie is
  movies_DF.dropna(subset = ["language"], inplace=True) #drops rows that have NaN as their language value
  movies_DF = movies_DF[movies_DF.language != "None"]

  for i in movies_DF['language'].values:
      #print(i, len(i))
      if(i[0:4] == "None"):
          #print("This is None!")
          #print("New value is: ", i[6:])
        i = i[6:]
      #print(i, len(i))

  genre_DF = movies_DF[movies_DF['genre'].str.contains(genre)]

  
  moviesPicked = movieSelection(genre_DF) 
  return moviesPicked

# %% [markdown]
# #Getting Random Movies

# %%
# This can be made into a function  
def movieSelection(genre_DF):
  genre_DF = genre_DF[['title', 'description']].copy()# genre_DF is what we're randomly selecting from

  num_to_select = 5

  list_of_random_items = genre_DF.sample(n = num_to_select)

  list_of_random_items = list_of_random_items.values.tolist()

  first_random_movie_TITLE = list_of_random_items[0][0]
  first_random_movie_DESC = list_of_random_items[0][1]
  #print("Title of movie: %s,  Movie description: %s" %(first_random_movie_TITLE, first_random_movie_DESC) )
  print()

  second_random_movie_TITLE = list_of_random_items[1][0]
  second_random_movie_DESC = list_of_random_items[1][1]
  #print("Title of movie: %s,  Movie description: %s" %(second_random_movie_TITLE, second_random_movie_DESC) )
  print()

  third_random_movie_TITLE = list_of_random_items[2][0]
  third_random_movie_DESC = list_of_random_items[2][1]
  #print("Title of movie: %s,  Movie description: %s" %(third_random_movie_TITLE, third_random_movie_DESC) )
  print()

  fourth_random_movie_TITLE = list_of_random_items[3][0]
  fourth_random_movie_DESC = list_of_random_items[3][1]
  #print("Title of movie: %s,  Movie description: %s" %(fourth_random_movie_TITLE, fourth_random_movie_DESC) )
  print()

  fifth_random_movie_TITLE = list_of_random_items[4][0]
  fifth_random_movie_DESC = list_of_random_items[4][1]
  #print("Title of movie: %s,  Movie description: %s" %(fifth_random_movie_TITLE, fifth_random_movie_DESC) )
  print()

  movies = {first_random_movie_TITLE:first_random_movie_DESC ,second_random_movie_TITLE:second_random_movie_DESC ,third_random_movie_TITLE:third_random_movie_DESC ,fourth_random_movie_TITLE:fourth_random_movie_DESC ,fifth_random_movie_TITLE:fifth_random_movie_DESC }
  return movies

# %%
movies_DF.head(10) #This is just for reference to see if the above worked out with hardcoded df
# Out:
#                                                title  ...                                        description
# 0                                          Cleopatra  ...  The fabled queen of Egypt's affair with Roman ...
# 1                                          L'Inferno  ...  Loosely adapted from Dante's Divine Comedy and...
# 2  From the Manger to the Cross; or, Jesus of Naz...  ...  An account of the life of Jesus Christ, based ...
# 3                                     Madame DuBarry  ...  The story of Madame DuBarry, the mistress of L...
# 4                                         Quo Vadis?  ...  An epic Italian film "Quo Vadis" influenced ma...
# 5                                        Richard III  ...  Richard of Gloucester uses manipulation and mu...
# 6                                           Atlantis  ...  After Dr. Friedrich's wife becomes mentally un...
# 7              Fantômas - À l'ombre de la guillotine  ...  Inspector Juve is tasked to investigate and ca...
# 8                               Juve contre Fantômas  ...  In Part Two of Louis Feuillade's 5 1/2-hour ep...
# 9                         Ma l'amor mio non muore...  ...  Leslie Swayne, an adventurer, in order to obta...
#
# [10 rows x 4 columns]

# %% [markdown]
# # User menu

# %%
choice=True
while choice:
    print("""
    1: Action
    2: Adventure
    3: Biography
    4: Comedy
    5: Crime
    6: Drama
    7: Family
    8: Fantasy
    9: History
    10: Horror
    11: Mystery
    12: Romance
    13: Sci-Fi
    14: Sport
    15: Thriller
    16: War
    17: Western
    18: Quit
    """)
    choice=input("What movie genre would you like to watch?\n")
    
    if choice=="1":
        print("You've chosen Action movies\n")
        choice = 'Action'
        userMovie = genreDF(choice)
        for key,value in userMovie.items():
          print(key)
          print(value)
          print()
        userRepeat = input("Would you like to choose another 5 movies? (Yes/No): ")
        if userRepeat.upper() == "YES":
          continue
        else:
          break
        
    elif choice=="2":
        print("You've chosen Adventure movies\n")
        choice = 'Adventure'
        userMovie = genreDF(choice)
        for key,value in userMovie.items():
          print(key)
          print(value)
          print()
        userRepeat = input("Would you like to choose another 5 movies? (Yes/No): ")
        if userRepeat.upper() == "YES":
          continue
        else:
          break

    elif choice=="3":
        print("You've chosen Biography movies\n")
        choice = 'Biography'
        userMovie = genreDF(choice)
        for key,value in userMovie.items():
          print(key)
          print(value)
          print()
        userRepeat = input("Would you like to choose another 5 movies? (Yes/No): ")
        if userRepeat.upper() == "YES":
          continue
        else:
          break

    elif choice=="4":
        print("You've chosen Comedy movies\n")
        choice = 'Comedy'
        userMovie = genreDF(choice)
        for key,value in userMovie.items():
          print(key)
          print(value)
          print()
        userRepeat = input("Would you like to choose another 5 movies? (Yes/No): ")
        if userRepeat.upper() == "YES":
          continue
        else:
          break

    elif choice=="5":
        print("You've chosen Crime movies\n")
        choice = 'Crime'
        userMovie = genreDF(choice)
        for key,value in userMovie.items():
          print(key)
          print(value)
          print()
        userRepeat = input("Would you like to choose another 5 movies? (Yes/No): ")
        if userRepeat.upper() == "YES":
          continue
        else:
          break

    elif choice=="6":
        print("You've chosen Drama movies\n")
        choice = 'Drama'
        userMovie = genreDF(choice)
        for key,value in userMovie.items():
          print(key)
          print(value)
          print()
        userRepeat = input("Would you like to choose another 5 movies? (Yes/No): ")
        if userRepeat.upper() == "YES":
          continue
        else:
          break

    elif choice=="7":
        print("You've chosen Family movies\n")
        choice = 'Family'
        userMovie = genreDF(choice)
        for key,value in userMovie.items():
          print(key)
          print(value)
          print()
        userRepeat = input("Would you like to choose another 5 movies? (Yes/No): ")
        if userRepeat.upper() == "YES":
          continue
        else:
          break

    elif choice=="8":
        print("You've chosen Fantasy movies\n")
        choice = 'Fantasy'
        userMovie = genreDF(choice)
        for key,value in userMovie.items():
          print(key)
          print(value)
          print()
        userRepeat = input("Would you like to choose another 5 movies? (Yes/No): ")
        if userRepeat.upper() == "YES":
          continue
        else:
          break

    elif choice=="9":
        print("You've chosen History movies\n")
        choice = 'History'
        userMovie = genreDF(choice)
        for key,value in userMovie.items():
          print(key)
          print(value)
          print()
        userRepeat = input("Would you like to choose another 5 movies? (Yes/No): ")
        if userRepeat.upper() == "YES":
          continue
        else:
          break

    elif choice=="10":
        print("You've chosen Horror movies\n")
        choice = 'Horror'
        userMovie = genreDF(choice)
        for key,value in userMovie.items():
          print(key)
          print(value)
          print()
        userRepeat = input("Would you like to choose another 5 movies? (Yes/No): ")
        if userRepeat.upper() == "YES":
          continue
        else:
          break

    elif choice=="11":
        print("You've chosen Mystery movies\n")
        choice = 'Mystery'
        userMovie = genreDF(choice)
        for key,value in userMovie.items():
          print(key)
          print(value)
          print()
        userRepeat = input("Would you like to choose another 5 movies? (Yes/No): ")
        if userRepeat.upper() == "YES":
          continue
        else:
          break

    elif choice=="12":
        print("You've chosen Romance movies\n")
        choice = 'Romance'
        userMovie = genreDF(choice)
        for key,value in userMovie.items():
          print(key)
          print(value)
          print()
        userRepeat = input("Would you like to choose another 5 movies? (Yes/No): ")
        if userRepeat.upper() == "YES":
          continue
        else:
          break

    elif choice=="13":
        print("You've chosen Sci-Fi movies\n")
        choice = 'Sci-Fi'
        userMovie = genreDF(choice)
        for key,value in userMovie.items():
          print(key)
          print(value)
          print()
        userRepeat = input("Would you like to choose another 5 movies? (Yes/No): ")
        if userRepeat.upper() == "YES":
          continue
        else:
          break

    elif choice=="14":
        print("You've chosen Sport movies\n")
        choice = 'Sport'
        userMovie = genreDF(choice)
        for key,value in userMovie.items():
          print(key)
          print(value)
          print()
        userRepeat = input("Would you like to choose another 5 movies? (Yes/No): ")
        if userRepeat.upper() == "YES":
          continue
        else:
          break

    elif choice=="15":
        print("You've chosen Thriller movies\n")
        choice = 'Thriller'
        userMovie = genreDF(choice)
        for key,value in userMovie.items():
          print(key)
          print(value)
          print()
        userRepeat = input("Would you like to choose another 5 movies? (Yes/No): ")
        if userRepeat.upper() == "YES":
          continue
        else:
          break

    elif choice=="16":
        print("You've chosen War movies\n")
        choice = 'War'
        userMovie = genreDF(choice)
        for key,value in userMovie.items():
          print(key)
          print(value)
          print()
        userRepeat = input("Would you like to choose another 5 movies? (Yes/No): ")
        if userRepeat.upper() == "YES":
          continue
        else:
          break

    elif choice=="17":
        print("You've chosen Western movies\n")
        choice = 'Western'
        userMovie = genreDF(choice)
        for key,value in userMovie.items():
          print(key)
          print(value)
          print()
        userRepeat = input("Would you like to choose another 5 movies? (Yes/No): ")
        if userRepeat.upper() == "YES":
          continue
        else:
          break

    elif choice=="18":
        print("Goodbye")
        break
        
    else:
        print("Not a Valid Choice. Please try again.\n")
# Out:
#     1: Action
#     2: Adventure
#     3: Biography
#     4: Comedy
#     5: Crime
#     6: Drama
#     7: Family
#     8: Fantasy
#     9: History
#     10: Horror
#     11: Mystery
#     12: Romance
#     13: Sci-Fi
#     14: Sport
#     15: Thriller
#     16: War
#     17: Western
#     18: Quit
#
# What movie genre would you like to watch?
# 2
# You've chosen Adventure movies
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2822: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# Chi ha incastrato Roger Rabbit
# A toon-hating detective is a cartoon rabbit's only hope to prove his innocence when he is accused of murder.
#
# Il ritorno di Godzilla
# A young man steals a boat to find his brother, but he and his shipmates become shipwrecked on a mysterious island inhabited by a giant sea monster and a slumbering Godzilla.
#
# Gioco di massacro
# Two cartoonists meet a playboy who lives out the fantasies created in their cartoons. He hires them to create a new comic strip. As they work on the new strip, the playboy begins to live it...
#
# Box 507
# The daughter of bankmanager Modesto Pardo (played by Antonio Resines) dies in an forest fire while camping. 7 years later Pardo's bank gets robbed and robbers break open numerous safe ...
#
# Il mercenario della morte
# After her husband is gunned down, Rose Hood takes his place temporarily as Marshal of a small Western town.
#
# Would you like to choose another 5 movies? (Yes/No): no
